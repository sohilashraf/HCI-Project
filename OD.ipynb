# %%
import cv2
from ultralytics import YOLO
import socket
import threading
import pygame
import sys
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.2)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
model = YOLO(r"C:\Users\sohila\MSA\semester 7\HCI\Object Detection\best.pt")
print("Model classes:", model.names)
# Out:
# Model classes: {0: 'Past', 1: 'Tut'}

# %%
# HOST = '127.0.0.1'  # Server's hostname or IP address
# PORT = 65434       # Server's port

# client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
# client_socket.connect((HOST, PORT))

target_class_names = ["Past", "Tut"]
target_classes = [index for index, name in model.names.items() if name in target_class_names]
print("Target class indices:", target_classes)

cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open the camera.")
    exit()

# List to store detected objects (names and confidence)
detected_objects = []

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    if not ret:
        print("Error: Failed to capture image.")
        break

    # Resize the frame to 640x640 (YOLO default size)
    frame_resized = cv2.resize(frame, (640, 640))

    # Perform YOLO inference
    results = model(frame_resized, conf=0.5, classes=target_classes)  # Lower confidence threshold

    # Get the first result
    result = results[0]
   

    # Print the full result for debugging
    #print("Result:", result)

    # Annotate the frame with the results
    # annotated_frame = result.plot()  # Adds bounding boxes, labels, etc.

    #Check if there are detections
    if len(result.boxes.cls) > 0:
        print("Detected classes and their confidences:")
        for box, score, cls in zip(result.boxes.xywh, result.boxes.conf, result.boxes.cls):
            class_name = model.names[int(cls)]  # Get class name
            confidence = float(score)  # Get confidence score
            print(f"Class: {class_name}, Confidence: {confidence:.2f}")

            # Only add target classes to the list
            # if class_name in target_class_names:
            #     detected_objects.append((class_name, confidence))
            #     print(f"Detected target class: {class_name} with confidence: {confidence:.2f}")
            #     message = f"Object ID: {class_name}"
            #     # client_socket.sendall(message.encode())
            # else:
            #     print(f"Detected non-target class: {class_name} with confidence: {confidence:.2f}")
            #     message = f"Object ID: {class_name}"
            #     # client_socket.sendall(message.encode())
    else:
        print("No target objects detected.")

    # Display the annotated frame
    cv2.imshow("YOLO Object Detection", annotated_frame)

    # Wait for the 'q' key to be pressed, and break the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("\n--- Detected Objects ---")
        for obj in detected_objects:
            print(f"Class: {obj[0]}, Confidence: {obj[1]:.2f}")
        break

# Release the capture object and close any OpenCV windows
cap.release()
cv2.destroyAllWindows()
print(detected_objects)
# Out:
# Target class indices: [0, 1]
#
# 0: 640x640 (no detections), 77.5ms
# Speed: 4.0ms preprocess, 77.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 1 Tut, 87.1ms
# Speed: 4.0ms preprocess, 87.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.56
#
# 0: 640x640 (no detections), 73.6ms
# Speed: 2.0ms preprocess, 73.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 1 Tut, 71.5ms
# Speed: 4.0ms preprocess, 71.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.75
#
# 0: 640x640 1 Tut, 65.3ms
# Speed: 3.0ms preprocess, 65.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.79
#
# 0: 640x640 1 Tut, 91.5ms
# Speed: 2.0ms preprocess, 91.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.88
#
# 0: 640x640 1 Tut, 67.1ms
# Speed: 2.0ms preprocess, 67.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.65
#
# 0: 640x640 1 Tut, 62.5ms
# Speed: 2.0ms preprocess, 62.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.81
#
# 0: 640x640 1 Tut, 58.6ms
# Speed: 3.0ms preprocess, 58.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.82
#
# 0: 640x640 1 Tut, 62.9ms
# Speed: 2.0ms preprocess, 62.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.84
#
# 0: 640x640 1 Tut, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.74
#
# 0: 640x640 (no detections), 101.0ms
# Speed: 2.0ms preprocess, 101.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 1 Tut, 64.4ms
# Speed: 2.0ms preprocess, 64.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.65
#
# 0: 640x640 1 Tut, 67.1ms
# Speed: 3.4ms preprocess, 67.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.65
#
# 0: 640x640 (no detections), 66.2ms
# Speed: 2.0ms preprocess, 66.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 66.5ms
# Speed: 2.0ms preprocess, 66.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 61.5ms
# Speed: 3.0ms preprocess, 61.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 63.1ms
# Speed: 2.0ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 62.7ms
# Speed: 3.0ms preprocess, 62.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 61.0ms
# Speed: 4.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 62.5ms
# Speed: 2.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 62.1ms
# Speed: 3.0ms preprocess, 62.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 68.8ms
# Speed: 2.0ms preprocess, 68.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 71.9ms
# Speed: 3.0ms preprocess, 71.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 71.7ms
# Speed: 3.0ms preprocess, 71.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 80.7ms
# Speed: 3.0ms preprocess, 80.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 71.5ms
# Speed: 2.0ms preprocess, 71.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 68.7ms
# Speed: 3.0ms preprocess, 68.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 67.5ms
# Speed: 3.0ms preprocess, 67.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 66.1ms
# Speed: 2.0ms preprocess, 66.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 68.6ms
# Speed: 3.0ms preprocess, 68.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 66.6ms
# Speed: 3.0ms preprocess, 66.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 73.0ms
# Speed: 3.0ms preprocess, 73.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 75.0ms
# Speed: 2.0ms preprocess, 75.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 76.5ms
# Speed: 3.0ms preprocess, 76.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 79.5ms
# Speed: 3.0ms preprocess, 79.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 81.5ms
# Speed: 3.0ms preprocess, 81.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 108.0ms
# Speed: 8.0ms preprocess, 108.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 92.5ms
# Speed: 3.0ms preprocess, 92.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 87.5ms
# Speed: 3.0ms preprocess, 87.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 85.5ms
# Speed: 2.0ms preprocess, 85.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 87.5ms
# Speed: 3.0ms preprocess, 87.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 77.0ms
# Speed: 2.5ms preprocess, 77.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 77.5ms
# Speed: 3.0ms preprocess, 77.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 76.5ms
# Speed: 3.0ms preprocess, 76.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 83.5ms
# Speed: 3.0ms preprocess, 83.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 92.5ms
# Speed: 4.0ms preprocess, 92.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 89.0ms
# Speed: 4.0ms preprocess, 89.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 84.0ms
# Speed: 3.0ms preprocess, 84.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 73.0ms
# Speed: 4.0ms preprocess, 73.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 74.0ms
# Speed: 3.0ms preprocess, 74.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 1 Tut, 74.5ms
# Speed: 3.0ms preprocess, 74.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.83
#
# 0: 640x640 (no detections), 74.5ms
# Speed: 4.0ms preprocess, 74.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 74.5ms
# Speed: 3.0ms preprocess, 74.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 1 Tut, 75.5ms
# Speed: 3.0ms preprocess, 75.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.81
#
# 0: 640x640 1 Tut, 76.5ms
# Speed: 3.0ms preprocess, 76.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.83
#
# 0: 640x640 1 Tut, 98.8ms
# Speed: 4.0ms preprocess, 98.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.80
#
# 0: 640x640 1 Tut, 100.5ms
# Speed: 4.3ms preprocess, 100.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.84
#
# 0: 640x640 1 Tut, 86.5ms
# Speed: 4.0ms preprocess, 86.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.88
#
# 0: 640x640 1 Tut, 80.5ms
# Speed: 3.0ms preprocess, 80.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.82
#
# 0: 640x640 1 Tut, 75.5ms
# Speed: 4.0ms preprocess, 75.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.84
#
# 0: 640x640 1 Tut, 74.6ms
# Speed: 3.0ms preprocess, 74.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.81
#
# 0: 640x640 1 Tut, 72.0ms
# Speed: 3.0ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.74
#
# 0: 640x640 1 Tut, 74.0ms
# Speed: 3.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.70
#
# 0: 640x640 1 Tut, 74.0ms
# Speed: 3.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.76
#
# 0: 640x640 1 Tut, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.85
#
# 0: 640x640 1 Tut, 76.0ms
# Speed: 3.0ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.78
#
# 0: 640x640 1 Tut, 76.0ms
# Speed: 3.0ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.80
#
# 0: 640x640 1 Tut, 76.0ms
# Speed: 3.0ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.71
#
# 0: 640x640 1 Tut, 76.5ms
# Speed: 3.0ms preprocess, 76.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.68
#
# 0: 640x640 (no detections), 74.5ms
# Speed: 3.0ms preprocess, 74.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 78.9ms
# Speed: 4.0ms preprocess, 78.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 77.5ms
# Speed: 3.0ms preprocess, 77.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 86.5ms
# Speed: 3.0ms preprocess, 86.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 91.5ms
# Speed: 4.0ms preprocess, 91.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 87.5ms
# Speed: 4.0ms preprocess, 87.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 89.6ms
# Speed: 4.0ms preprocess, 89.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 85.0ms
# Speed: 3.0ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 81.5ms
# Speed: 3.0ms preprocess, 81.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 78.0ms
# Speed: 3.0ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 82.0ms
# Speed: 4.0ms preprocess, 82.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 82.5ms
# Speed: 3.0ms preprocess, 82.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 106.5ms
# Speed: 3.0ms preprocess, 106.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 88.5ms
# Speed: 4.0ms preprocess, 88.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 86.5ms
# Speed: 4.0ms preprocess, 86.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 142.7ms
# Speed: 6.0ms preprocess, 142.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 143.0ms
# Speed: 6.0ms preprocess, 143.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 138.3ms
# Speed: 5.3ms preprocess, 138.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 141.7ms
# Speed: 6.0ms preprocess, 141.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 143.0ms
# Speed: 6.0ms preprocess, 143.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 142.5ms
# Speed: 6.2ms preprocess, 142.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 145.5ms
# Speed: 5.5ms preprocess, 145.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 187.4ms
# Speed: 7.0ms preprocess, 187.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 143.1ms
# Speed: 6.0ms preprocess, 143.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 1 Tut, 144.6ms
# Speed: 6.0ms preprocess, 144.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.69
#
# 0: 640x640 1 Tut, 141.0ms
# Speed: 6.0ms preprocess, 141.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.81
#
# 0: 640x640 1 Tut, 142.5ms
# Speed: 5.1ms preprocess, 142.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.88
#
# 0: 640x640 1 Tut, 141.3ms
# Speed: 6.0ms preprocess, 141.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.80
#
# 0: 640x640 (no detections), 143.9ms
# Speed: 6.4ms preprocess, 143.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 1 Tut, 145.0ms
# Speed: 6.0ms preprocess, 145.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.84
#
# 0: 640x640 1 Tut, 140.0ms
# Speed: 5.6ms preprocess, 140.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.80
#
# 0: 640x640 1 Tut, 142.2ms
# Speed: 4.2ms preprocess, 142.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.83
#
# 0: 640x640 1 Tut, 142.6ms
# Speed: 6.0ms preprocess, 142.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.81
#
# 0: 640x640 (no detections), 137.7ms
# Speed: 6.0ms preprocess, 137.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 142.9ms
# Speed: 6.0ms preprocess, 142.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 1 Tut, 144.9ms
# Speed: 4.2ms preprocess, 144.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.82
#
# 0: 640x640 1 Tut, 144.7ms
# Speed: 3.0ms preprocess, 144.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.77
#
# 0: 640x640 1 Tut, 142.8ms
# Speed: 6.7ms preprocess, 142.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.75
#
# 0: 640x640 1 Tut, 140.2ms
# Speed: 6.0ms preprocess, 140.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.63
#
# 0: 640x640 1 Tut, 141.5ms
# Speed: 6.2ms preprocess, 141.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.73
#
# 0: 640x640 1 Tut, 141.2ms
# Speed: 6.0ms preprocess, 141.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.75
#
# 0: 640x640 (no detections), 142.0ms
# Speed: 6.0ms preprocess, 142.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 1 Tut, 141.4ms
# Speed: 6.3ms preprocess, 141.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.79
#
# 0: 640x640 1 Tut, 146.3ms
# Speed: 6.0ms preprocess, 146.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.82
#
# 0: 640x640 1 Tut, 142.5ms
# Speed: 5.1ms preprocess, 142.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.79
#
# 0: 640x640 1 Tut, 142.0ms
# Speed: 5.0ms preprocess, 142.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.63
#
# 0: 640x640 (no detections), 138.2ms
# Speed: 7.0ms preprocess, 138.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 1 Tut, 140.0ms
# Speed: 6.0ms preprocess, 140.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.57
#
# 0: 640x640 1 Tut, 142.1ms
# Speed: 5.3ms preprocess, 142.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.64
#
# 0: 640x640 1 Tut, 144.1ms
# Speed: 6.0ms preprocess, 144.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.68
#
# 0: 640x640 1 Tut, 141.1ms
# Speed: 6.0ms preprocess, 141.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.78
#
# 0: 640x640 1 Tut, 141.8ms
# Speed: 5.0ms preprocess, 141.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.72
#
# 0: 640x640 1 Tut, 142.6ms
# Speed: 6.0ms preprocess, 142.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.78
#
# 0: 640x640 1 Tut, 142.9ms
# Speed: 6.0ms preprocess, 142.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.77
#
# 0: 640x640 1 Tut, 144.0ms
# Speed: 7.0ms preprocess, 144.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.80
#
# 0: 640x640 1 Tut, 142.6ms
# Speed: 6.0ms preprocess, 142.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.76
#
# 0: 640x640 (no detections), 143.4ms
# Speed: 6.1ms preprocess, 143.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 1 Tut, 146.8ms
# Speed: 6.0ms preprocess, 146.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.81
#
# 0: 640x640 1 Tut, 157.1ms
# Speed: 6.0ms preprocess, 157.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.76
#
# 0: 640x640 1 Tut, 141.1ms
# Speed: 6.0ms preprocess, 141.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.57
#
# 0: 640x640 1 Tut, 145.0ms
# Speed: 6.0ms preprocess, 145.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.62
#
# 0: 640x640 1 Tut, 142.4ms
# Speed: 5.4ms preprocess, 142.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.70
#
# 0: 640x640 1 Tut, 141.9ms
# Speed: 6.0ms preprocess, 141.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.57
#
# 0: 640x640 1 Tut, 141.4ms
# Speed: 6.0ms preprocess, 141.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.57
#
# 0: 640x640 1 Tut, 138.4ms
# Speed: 6.5ms preprocess, 138.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.54
#
# 0: 640x640 1 Tut, 142.7ms
# Speed: 5.0ms preprocess, 142.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.61
#
# 0: 640x640 (no detections), 142.6ms
# Speed: 5.0ms preprocess, 142.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 1 Tut, 139.7ms
# Speed: 6.0ms preprocess, 139.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.66
#
# 0: 640x640 1 Tut, 142.3ms
# Speed: 6.0ms preprocess, 142.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.51
#
# 0: 640x640 (no detections), 141.5ms
# Speed: 6.0ms preprocess, 141.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 139.8ms
# Speed: 6.1ms preprocess, 139.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 1 Tut, 141.6ms
# Speed: 6.0ms preprocess, 141.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.76
#
# 0: 640x640 (no detections), 146.8ms
# Speed: 6.3ms preprocess, 146.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 1 Tut, 142.8ms
# Speed: 6.0ms preprocess, 142.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.73
#
# 0: 640x640 1 Tut, 139.3ms
# Speed: 6.4ms preprocess, 139.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.79
#
# 0: 640x640 (no detections), 141.2ms
# Speed: 6.0ms preprocess, 141.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 144.1ms
# Speed: 6.0ms preprocess, 144.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 141.6ms
# Speed: 6.0ms preprocess, 141.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 138.5ms
# Speed: 7.1ms preprocess, 138.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 146.5ms
# Speed: 6.0ms preprocess, 146.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 143.0ms
# Speed: 6.8ms preprocess, 143.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 154.5ms
# Speed: 5.0ms preprocess, 154.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 142.1ms
# Speed: 5.3ms preprocess, 142.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 141.7ms
# Speed: 6.0ms preprocess, 141.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 1 Tut, 140.6ms
# Speed: 7.0ms preprocess, 140.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.50
#
# 0: 640x640 (no detections), 143.7ms
# Speed: 6.0ms preprocess, 143.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 1 Tut, 142.6ms
# Speed: 5.0ms preprocess, 142.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.65
#
# 0: 640x640 (no detections), 142.7ms
# Speed: 7.3ms preprocess, 142.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 143.5ms
# Speed: 7.0ms preprocess, 143.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 1 Tut, 144.4ms
# Speed: 6.0ms preprocess, 144.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.65
#
# 0: 640x640 (no detections), 141.7ms
# Speed: 6.0ms preprocess, 141.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 1 Tut, 140.0ms
# Speed: 5.0ms preprocess, 140.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.51
#
# 0: 640x640 1 Tut, 143.0ms
# Speed: 6.0ms preprocess, 143.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.61
#
# 0: 640x640 (no detections), 140.2ms
# Speed: 3.1ms preprocess, 140.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 179.7ms
# Speed: 6.0ms preprocess, 179.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 144.2ms
# Speed: 4.0ms preprocess, 144.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 145.1ms
# Speed: 6.0ms preprocess, 145.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 1 Tut, 145.8ms
# Speed: 6.5ms preprocess, 145.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.73
#
# 0: 640x640 (no detections), 145.6ms
# Speed: 6.4ms preprocess, 145.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 1 Tut, 146.0ms
# Speed: 6.0ms preprocess, 146.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.55
#
# 0: 640x640 1 Tut, 130.1ms
# Speed: 5.1ms preprocess, 130.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.65
#
# 0: 640x640 (no detections), 133.9ms
# Speed: 4.0ms preprocess, 133.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 1 Tut, 148.8ms
# Speed: 5.2ms preprocess, 148.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.53
#
# 0: 640x640 1 Tut, 142.0ms
# Speed: 5.0ms preprocess, 142.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.56
#
# 0: 640x640 1 Tut, 142.9ms
# Speed: 4.8ms preprocess, 142.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.57
#
# 0: 640x640 1 Tut, 146.4ms
# Speed: 5.5ms preprocess, 146.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected classes and their confidences:
# Class: Tut, Confidence: 0.58
#
# 0: 640x640 (no detections), 139.6ms
# Speed: 6.0ms preprocess, 139.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 140.0ms
# Speed: 6.0ms preprocess, 140.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 143.1ms
# Speed: 6.0ms preprocess, 143.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 138.7ms
# Speed: 4.5ms preprocess, 138.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 129.8ms
# Speed: 3.0ms preprocess, 129.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 126.3ms
# Speed: 4.3ms preprocess, 126.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 143.9ms
# Speed: 5.0ms preprocess, 143.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 148.4ms
# Speed: 6.0ms preprocess, 148.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 144.5ms
# Speed: 5.4ms preprocess, 144.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 148.6ms
# Speed: 6.3ms preprocess, 148.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 144.7ms
# Speed: 4.4ms preprocess, 144.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 142.9ms
# Speed: 5.0ms preprocess, 142.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 145.9ms
# Speed: 6.0ms preprocess, 145.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 147.4ms
# Speed: 4.1ms preprocess, 147.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 144.7ms
# Speed: 4.6ms preprocess, 144.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 156.3ms
# Speed: 6.0ms preprocess, 156.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 152.5ms
# Speed: 5.0ms preprocess, 152.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 159.7ms
# Speed: 6.1ms preprocess, 159.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 155.1ms
# Speed: 6.0ms preprocess, 155.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 155.5ms
# Speed: 6.0ms preprocess, 155.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 153.3ms
# Speed: 4.5ms preprocess, 153.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 151.7ms
# Speed: 5.0ms preprocess, 151.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 154.1ms
# Speed: 5.3ms preprocess, 154.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 159.9ms
# Speed: 6.3ms preprocess, 159.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 166.7ms
# Speed: 7.0ms preprocess, 166.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 159.7ms
# Speed: 6.8ms preprocess, 159.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 158.3ms
# Speed: 6.5ms preprocess, 158.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 154.8ms
# Speed: 4.8ms preprocess, 154.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 144.9ms
# Speed: 5.0ms preprocess, 144.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 144.0ms
# Speed: 7.0ms preprocess, 144.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 140.3ms
# Speed: 6.0ms preprocess, 140.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 137.3ms
# Speed: 6.0ms preprocess, 137.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 147.4ms
# Speed: 4.0ms preprocess, 147.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 146.2ms
# Speed: 6.0ms preprocess, 146.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 149.3ms
# Speed: 6.0ms preprocess, 149.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 147.7ms
# Speed: 7.8ms preprocess, 147.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 147.3ms
# Speed: 6.3ms preprocess, 147.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 144.4ms
# Speed: 6.0ms preprocess, 144.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 141.2ms
# Speed: 5.0ms preprocess, 141.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 147.1ms
# Speed: 6.0ms preprocess, 147.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 155.0ms
# Speed: 6.0ms preprocess, 155.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 153.5ms
# Speed: 7.0ms preprocess, 153.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 157.6ms
# Speed: 6.0ms preprocess, 157.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 157.5ms
# Speed: 5.0ms preprocess, 157.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 155.8ms
# Speed: 6.0ms preprocess, 155.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 155.9ms
# Speed: 4.5ms preprocess, 155.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 151.9ms
# Speed: 6.4ms preprocess, 151.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 152.1ms
# Speed: 7.4ms preprocess, 152.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 162.3ms
# Speed: 3.5ms preprocess, 162.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 212.2ms
# Speed: 6.0ms preprocess, 212.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 107.4ms
# Speed: 13.0ms preprocess, 107.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 73.5ms
# Speed: 2.0ms preprocess, 73.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 79.5ms
# Speed: 4.0ms preprocess, 79.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 80.5ms
# Speed: 2.0ms preprocess, 80.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 75.6ms
# Speed: 3.0ms preprocess, 75.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 76.6ms
# Speed: 3.0ms preprocess, 76.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 72.0ms
# Speed: 2.0ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 69.0ms
# Speed: 3.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 68.5ms
# Speed: 2.0ms preprocess, 68.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 69.0ms
# Speed: 3.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# 0: 640x640 (no detections), 62.9ms
# Speed: 2.0ms preprocess, 62.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No target objects detected.
#
# --- Detected Objects ---
# []
